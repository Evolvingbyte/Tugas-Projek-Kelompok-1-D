# %% [markdown]
# ### Matrix Multiplication Exercise

# %%
import torch

# %%
a = torch.tensor([[12, 22, 23], [24, 25, 26], [32, 31, 30]])
M_q
# Out:
# tensor([[12, 22, 23],
#         [24, 25, 26],
#         [32, 31, 30]])

# %%
b = torch.tensor([[-1, 2, -3], [4, 5, -6]]).T
V_q
# Out:
# tensor([[-1,  4],
#         [ 2,  5],
#         [-3, -6]])

# %%
torch.matmul(M_q, V_q)
# Out:
# tensor([[-37,  20],
#         [-52,  65],
#         [-60, 103]])
